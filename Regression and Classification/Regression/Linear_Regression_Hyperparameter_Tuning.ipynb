# %% [markdown]
# # Predict a numeric/continuous value

# %% [markdown]
# ## Linear Learner
#
# https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner.html

# %% [markdown]
# # Prepare the Environment

# %% [markdown]
# ## Upgrade the version of boto3 and sagemaker

# %%
# %pip install -qU --upgrade boto3
# %pip install -qU --upgrade sagemaker
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
import boto3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from time import gmtime, strftime

# %% [markdown]
# ## Setup your your environment variables

# %%
role = get_execution_role()
sess = sagemaker.Session() 
region = sess.boto_session.region_name
bucket = sess.default_bucket()
print("The role is ", role)
print("The session is ", sess)
print("The region is ", region)
print("The bucket is ", bucket)
# Out:
# The role is  arn:aws:iam::740729256087:role/LabRole
# The session is  <sagemaker.session.Session object at 0x7f6b0ef5f190>
# The region is  us-east-1
# The bucket is  sagemaker-us-east-1-740729256087

# %% [markdown]
# ## We are going to use Linear Learner to make predicitons based on the Boston Housing Dataset
#
# The Boston Housing Dataset
# [The Boston Housing Dataset](https://www.kaggle.com/code/prasadperera/the-boston-housing-dataset/data)
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# * CRIM - per capita crime rate by town
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * NOX - nitric oxides concentration (parts per 10 million)
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per \$10,000
# * PTRATIO - pupil-teacher ratio by town
# * B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# * LSTAT - % lower status of the population
# * MEDV - Median value of owner-occupied homes in \$1000's

# %% [markdown]
# # Prepare and Inspect the Data
# ## Download the Dataset to Jupyter Notebook and explore the data by opening it and note that the delimiters are spaces and that there are no headings

# %%
# Define the headers accordign to the despcription provided

columns = ['CRIM','ZN','INDUS','CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV' ]

# Load the dataset into a DataFrame usign whitespace as the delimiter. Make sure to tell it that the first row is not the header and include the column names we want to use

housing_data=pd.read_csv('housing.csv', delim_whitespace=True, header=None, names=columns)

# %%
housing_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# Linear learner can read csv but the the first column is assumed to ne the target label so we need to move MEDV to the first column

new_columns = ['MEDV','ZN','INDUS','CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'CRIM']
housing_data=housing_data.reindex(columns=new_columns)
housing_data.head()
# Out:
#    MEDV    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  24.0  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0     15.3
# 1  21.6   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0     17.8
# 2  34.7   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0     17.8
# 3  33.4   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0     18.7
# 4  36.2   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0     18.7
#
#         B  LSTAT     CRIM
# 0  396.90   4.98  0.00632
# 1  396.90   9.14  0.02731
# 2  392.83   4.03  0.02729
# 3  394.63   2.94  0.03237
# 4  396.90   5.33  0.06905

# %%
# Lets check to see if there are any missing values

housing_data.isnull().sum()
# Out:
# MEDV       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# CRIM       0
# dtype: int64

# %%
# Use describe to get some information about the data

housing_data.describe()
# Out:
#              MEDV          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.532806   11.363636   11.136779    0.069170    0.554695    6.284634
# std      9.197104   23.322453    6.860353    0.253994    0.115878    0.702617
# min      5.000000    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%     17.025000    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%     21.200000    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%     25.000000   12.500000   18.100000    0.000000    0.624000    6.623500
# max     50.000000  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        CRIM
# count  506.000000  506.000000
# mean    12.653063    3.613524
# std      7.141062    8.601545
# min      1.730000    0.006320
# 25%      6.950000    0.082045
# 50%     11.360000    0.256510
# 75%     16.955000    3.677083
# max     37.970000   88.976200

# %%
# Use a histogram to see if there are any outliers in the data - here I am only exploring the target values

plt.hist(housing_data['MEDV'], color='blue', edgecolor='black', bins=int(45/1))
plt.xlabel('Median value of owner-occupied homes in $1000')
plt.ylabel('No. of houses')
plt.title('Housing prices frequencies')
# Out:
# Text(0.5, 1.0, 'Housing prices frequencies')

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Shuffle and Split the data into 80% training and 20% testing

train_data, test_data = train_test_split(housing_data, test_size=0.2)

# Convert dataframes to back to CSV files and save them locally to the notebook and make sure to exclude the headers so taht Linear Learner will accept the file

train_data.to_csv('train.csv', header=False, index=False)
test_data.to_csv('test.csv', header=False, index=False)

# %%
# Copy the file to your S3 bucket using sess.upload_data
# You will need to pass the file to be uploaded, a prefix (top level folder to store the data) and the subfolders
# Here we will also define the output folder for the results

prefix = 'housing'
training_data_path = sess.upload_data( path='train.csv', key_prefix=prefix + '/input/train') 
testing_data_path = sess.upload_data( path='test.csv', key_prefix=prefix + '/input/test')
output_data_path = 's3://{}/{}/output'.format(bucket, prefix)
print(training_data_path)
print(testing_data_path)
print(output_data_path)
# Out:
# s3://sagemaker-us-east-1-740729256087/housing/input/train/train.csv
# s3://sagemaker-us-east-1-740729256087/housing/input/test/test.csv
# s3://sagemaker-us-east-1-740729256087/housing/output

# %% [markdown]
# # Train the Model

# %%
 # specify containers

from sagemaker.image_uris import retrieve


# List of frameworks that can be retrieved https://sagemaker.readthedocs.io/en/stable/frameworks/index.html
# list of Built-in Algorithms that can be retrieved https://sagemaker.readthedocs.io/en/stable/algorithms/index.html

container = retrieve('linear-learner', region)

# %%
# Amazon Estimator Documentation https://sagemaker.readthedocs.io/en/stable/algorithms/sagemaker.amazon.amazon_estimator.html

from sagemaker.estimator import Estimator 
ll_estimator = Estimator(container, 
                         role=role, 
                         instance_count=1, 
                         instance_type='ml.c4.xlarge', 
                         output_path=output_data_path)

# %%
# Set the linear learner hyperparameters
# hyperparameters can be found here https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html
# Here we will use the Hyperameter values for 


ll_estimator.set_hyperparameters(predictor_type='regressor')

# %%
# Creating a channel from the S3 data source and file system
# TrainingInput documentation https://sagemaker.readthedocs.io/en/stable/api/utility/inputs.html

from sagemaker import TrainingInput 
training_data_channel = TrainingInput( s3_data=training_data_path, content_type='text/csv') 
testing_data_channel = TrainingInput( s3_data=testing_data_path,   content_type='text/csv')

# %% [markdown]
# ## Find the best hyperparameters

# %%
# Hyperparameters = https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html
# Objectives = https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner-tuning.html

from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner

hypertuner = HyperparameterTuner(ll_estimator, 
                                 objective_metric_name = 'test:absolute_loss',
                                 hyperparameter_ranges = {
                                 'learning_rate' : ContinuousParameter(0.01, 0.1),
                                 'mini_batch_size': CategoricalParameter([32,64,128,256,512])},
                                 objective_type = 'Minimize',
                                 metric_definitions = [{'Name': 'test:absolute_loss', 'Regex': 'loss (\S+)'}],
                                 max_jobs=10, 
                                 max_parallel_jobs=1
                                )

# %%
hypertuner.fit( {'train': training_data_channel, 'test': testing_data_channel})
# Out:
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# ................................................................................................................................!

# %%
print("Best hyerparameter tuning job:{}".format(hypertuner.best_training_job()))
print("Best parameters found={}".format(hypertuner.best_estimator().hyperparameters()))
# Out:
# Best hyerparameter tuning job:linear-learner-230202-1604-007-ffec218a
#
# 2023-02-02 16:12:52 Starting - Found matching resource for reuse
# 2023-02-02 16:12:52 Downloading - Downloading input data
# 2023-02-02 16:12:52 Training - Training image download completed. Training in progress.
# 2023-02-02 16:12:52 Uploading - Uploading generated training model
# 2023-02-02 16:12:52 Completed - Resource reused by training job: linear-learner-230202-1604-008-cb0d966c
# Best parameters found={'_tuning_objective_metric': 'test:absolute_loss', 'learning_rate': '0.018266315065397474', 'mini_batch_size': '128', 'predictor_type': 'regressor'}

# %% [markdown]
# # Train the Model

# %%
# Set the linear learner hyperparameters
# hyperparameters can be found here https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html
# We will use the values discovered about for learning_rate and mini_batch_size

ll_estimator.set_hyperparameters(feature_dim=13, # There are 13 feature columns
                                 predictor_type='regressor',
                                 mini_batch_size=128,
                                 learning_rate=0.018266315065397474)

# %%
# Now we are going to Fit the model
# Documentaiton for FIT https://sagemaker.readthedocs.io/en/stable/algorithms/sagemaker.amazon.amazon_estimator.html#sagemaker.amazon.amazon_estimator.AmazonAlgorithmEstimatorBase.fit

ll_estimator.fit( {'train': training_data_channel, 'test': testing_data_channel})
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2023-02-02-16-20-19-995
# 2023-02-02 16:20:20 Starting - Starting the training job...
# 2023-02-02 16:20:39 Starting - Preparing the instances for training......
# 2023-02-02 16:21:46 Downloading - Downloading input data...
# 2023-02-02 16:22:11 Training - Downloading the training image...........Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/02/2023 16:23:59 INFO 140073518991168] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/02/2023 16:23:59 INFO 140073518991168] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '13', 'learning_rate': '0.018266315065397474', 'mini_batch_size': '128', 'predictor_type': 'regressor'}
# [02/02/2023 16:23:59 INFO 140073518991168] Final configuration: {'mini_batch_size': '128', 'epochs': '15', 'feature_dim': '13', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.018266315065397474', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [02/02/2023 16:24:02 WARNING 140073518991168] Loggers have already been setup.
# [02/02/2023 16:24:02 INFO 140073518991168] Final configuration: {'mini_batch_size': '128', 'epochs': '15', 'feature_dim': '13', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.018266315065397474', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [02/02/2023 16:24:02 WARNING 140073518991168] Loggers have already been setup.
# Process 7 is a worker.
# [02/02/2023 16:24:02 INFO 140073518991168] Using default worker.
# [02/02/2023 16:24:02 INFO 140073518991168] Checkpoint loading and saving are disabled.
# [02/02/2023 16:24:02 INFO 140073518991168] Create Store: local
# [02/02/2023 16:24:02 INFO 140073518991168] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f64deb24910>
# [02/02/2023 16:24:02 INFO 140073518991168] Scaling model computed with parameters:
#  {'stdev_label':
# [9.299169]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [2.3354965e+01 6.8260760e+00 2.5567296e-01 1.1961239e-01 6.9229490e-01
#  2.8120344e+01 2.0594027e+00 8.7771835e+00 1.7113028e+02 2.1442719e+00
#  9.3187859e+01 7.3087602e+00 8.4341183e+00]
# <NDArray 13 @cpu(0)>, 'mean_label':
# [22.508333]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [1.1661459e+01 1.1053699e+01 7.0312500e-02 5.5757475e-01 6.3000159e+00
#  6.8551826e+01 3.7723355e+00 9.8645840e+00 4.1410678e+02 1.8493490e+01
#  3.5615616e+02 1.2706589e+01 3.5918341e+00]
# <NDArray 13 @cpu(0)>}
# [02/02/2023 16:24:02 INFO 140073518991168] nvidia-smi: took 0.033 seconds to run.
# [02/02/2023 16:24:02 INFO 140073518991168] nvidia-smi identified 0 GPUs.
# [02/02/2023 16:24:02 INFO 140073518991168] Number of GPUs being used: 0
# #metrics {"StartTime": 1675355042.8376675, "EndTime": 1675355042.8377006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 532.0, "count": 1, "min": 532, "max": 532}, "Total Batches Seen": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Records Seen Between Resets": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Max Batches Seen Between Resets": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1675355042.9407876, "EndTime": 1675355042.9408395, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.8895268638928732, "count": 1, "min": 0.8895268638928732, "max": 0.8895268638928732}}}
# #metrics {"StartTime": 1675355042.9409194, "EndTime": 1675355042.9409347, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.9135799606641134, "count": 1, "min": 0.9135799606641134, "max": 0.9135799606641134}}}
# #metrics {"StartTime": 1675355042.9409904, "EndTime": 1675355042.9410408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.8765567938486735, "count": 1, "min": 0.8765567938486735, "max": 0.8765567938486735}}}
# #metrics {"StartTime": 1675355042.9410913, "EndTime": 1675355042.9411075, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 1.3182499011357625, "count": 1, "min": 1.3182499011357625, "max": 1.3182499011357625}}}
# #metrics {"StartTime": 1675355042.941204, "EndTime": 1675355042.9412253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 1.1389339566230774, "count": 1, "min": 1.1389339566230774, "max": 1.1389339566230774}}}
# #metrics {"StartTime": 1675355042.9412875, "EndTime": 1675355042.941304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.121714214483897, "count": 1, "min": 1.121714214483897, "max": 1.121714214483897}}}
# #metrics {"StartTime": 1675355042.941402, "EndTime": 1675355042.941421, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 1.1809577544530232, "count": 1, "min": 1.1809577544530232, "max": 1.1809577544530232}}}
# #metrics {"StartTime": 1675355042.9414754, "EndTime": 1675355042.9414911, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.1782827774683635, "count": 1, "min": 1.1782827774683635, "max": 1.1782827774683635}}}
# #metrics {"StartTime": 1675355042.9415815, "EndTime": 1675355042.9416003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 1.1600365440050762, "count": 1, "min": 1.1600365440050762, "max": 1.1600365440050762}}}
# #metrics {"StartTime": 1675355042.9416473, "EndTime": 1675355042.9416628, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.8227700988451639, "count": 1, "min": 0.8227700988451639, "max": 0.8227700988451639}}}
# #metrics {"StartTime": 1675355042.941749, "EndTime": 1675355042.9417665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 1.2506975332895915, "count": 1, "min": 1.2506975332895915, "max": 1.2506975332895915}}}
# #metrics {"StartTime": 1675355042.9418275, "EndTime": 1675355042.941864, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.1280757983525593, "count": 1, "min": 1.1280757983525593, "max": 1.1280757983525593}}}
# #metrics {"StartTime": 1675355042.9419177, "EndTime": 1675355042.941934, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 1.136565109093984, "count": 1, "min": 1.136565109093984, "max": 1.136565109093984}}}
# #metrics {"StartTime": 1675355042.941983, "EndTime": 1675355042.9419992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 1.13042151927948, "count": 1, "min": 1.13042151927948, "max": 1.13042151927948}}}
# #metrics {"StartTime": 1675355042.9420595, "EndTime": 1675355042.9420772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 1.2332836588223774, "count": 1, "min": 1.2332836588223774, "max": 1.2332836588223774}}}
# #metrics {"StartTime": 1675355042.9421322, "EndTime": 1675355042.9421487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.194483995437622, "count": 1, "min": 1.194483995437622, "max": 1.194483995437622}}}
# #metrics {"StartTime": 1675355042.9422066, "EndTime": 1675355042.942223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.8663940032323202, "count": 1, "min": 0.8663940032323202, "max": 0.8663940032323202}}}
# #metrics {"StartTime": 1675355042.9422708, "EndTime": 1675355042.9422872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 1.213021159172058, "count": 1, "min": 1.213021159172058, "max": 1.213021159172058}}}
# #metrics {"StartTime": 1675355042.9423409, "EndTime": 1675355042.9423566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.783781091372172, "count": 1, "min": 0.783781091372172, "max": 0.783781091372172}}}
# #metrics {"StartTime": 1675355042.9424045, "EndTime": 1675355042.9424205, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 1.050925374031067, "count": 1, "min": 1.050925374031067, "max": 1.050925374031067}}}
# #metrics {"StartTime": 1675355042.942462, "EndTime": 1675355042.9424767, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 1.1419097979863484, "count": 1, "min": 1.1419097979863484, "max": 1.1419097979863484}}}
# #metrics {"StartTime": 1675355042.9425316, "EndTime": 1675355042.9425476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.9733476440111796, "count": 1, "min": 0.9733476440111796, "max": 0.9733476440111796}}}
# #metrics {"StartTime": 1675355042.9425976, "EndTime": 1675355042.9426136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 1.0895647207895915, "count": 1, "min": 1.0895647207895915, "max": 1.0895647207895915}}}
# #metrics {"StartTime": 1675355042.942664, "EndTime": 1675355042.9426801, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 1.254492163658142, "count": 1, "min": 1.254492163658142, "max": 1.254492163658142}}}
# #metrics {"StartTime": 1675355042.9427257, "EndTime": 1675355042.9427404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 1.1014264225959778, "count": 1, "min": 1.1014264225959778, "max": 1.1014264225959778}}}
# #metrics {"StartTime": 1675355042.942788, "EndTime": 1675355042.9428034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.1446597774823506, "count": 1, "min": 1.1446597774823506, "max": 1.1446597774823506}}}
# #metrics {"StartTime": 1675355042.9428754, "EndTime": 1675355042.9428906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9151012301445007, "count": 1, "min": 0.9151012301445007, "max": 0.9151012301445007}}}
# #metrics {"StartTime": 1675355042.9429386, "EndTime": 1675355042.942955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9572412371635437, "count": 1, "min": 0.9572412371635437, "max": 0.9572412371635437}}}
# #metrics {"StartTime": 1675355042.9430134, "EndTime": 1675355042.9430285, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.3102923432985942, "count": 1, "min": 1.3102923432985942, "max": 1.3102923432985942}}}
# #metrics {"StartTime": 1675355042.9430757, "EndTime": 1675355042.9430907, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.3118408521016438, "count": 1, "min": 1.3118408521016438, "max": 1.3118408521016438}}}
# #metrics {"StartTime": 1675355042.9431424, "EndTime": 1675355042.9431572, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.3823340733846028, "count": 1, "min": 1.3823340733846028, "max": 1.3823340733846028}}}
# #metrics {"StartTime": 1675355042.9432049, "EndTime": 1675355042.9432201, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.4501173098882039, "count": 1, "min": 1.4501173098882039, "max": 1.4501173098882039}}}
# [02/02/2023 16:24:02 INFO 140073518991168] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.8895268638928732
# [02/02/2023 16:24:02 INFO 140073518991168] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.783781091372172
# [02/02/2023 16:24:02 INFO 140073518991168] Epoch 0: Loss improved. Updating best model
# [02/02/2023 16:24:02 INFO 140073518991168] Saving model for epoch: 0
# [02/02/2023 16:24:02 INFO 140073518991168] Saved checkpoint to "/tmp/tmplr58042n/mx-mod-0000.params"
# [02/02/2023 16:24:02 INFO 140073518991168] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1675355042.837969, "EndTime": 1675355042.9568098, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 936.0, "count": 1, "min": 936, "max": 936}, "Total Batches Seen": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Max Records Seen Between Resets": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Max Batches Seen Between Resets": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Number of Batches Since Last Reset": {"sum": 4.0, "count": 1, "min": 4, "max": 4}}}
# [02/02/2023 16:24:02 INFO 140073518991168] #throughput_metric: host=algo-1, train throughput=3395.4013589630044 records/second
# #metrics {"StartTime": 1675355043.0556715, "EndTime": 1675355043.0557168, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.5330592592557272, "count": 1, "min": 0.5330592592557272, "max": 0.5330592592557272}}}
# #metrics {"StartTime": 1675355043.0557857, "EndTime": 1675355043.0558028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.7678775389989217, "count": 1, "min": 0.7678775389989217, "max": 0.7678775389989217}}}
# #metrics {"StartTime": 1675355043.0558636, "EndTime": 1675355043.0558786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.7337137659390768, "count": 1, "min": 0.7337137659390768, "max": 0.7337137659390768}}}
# #metrics {"StartTime": 1675355043.0559332, "EndTime": 1675355043.0559473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 1.1132086515426636, "count": 1, "min": 1.1132086515426636, "max": 1.1132086515426636}}}
# #metrics {"StartTime": 1675355043.055997, "EndTime": 1675355043.0560129, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.7610988815625509, "count": 1, "min": 0.7610988815625509, "max": 0.7610988815625509}}}
# #metrics {"StartTime": 1675355043.0560627, "EndTime": 1675355043.056079, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.7693802913029989, "count": 1, "min": 0.7693802913029989, "max": 0.7693802913029989}}}
# #metrics {"StartTime": 1675355043.056128, "EndTime": 1675355043.056138, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.798876682917277, "count": 1, "min": 0.798876682917277, "max": 0.798876682917277}}}
# #metrics {"StartTime": 1675355043.056163, "EndTime": 1675355043.05617, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.7602978746096293, "count": 1, "min": 0.7602978746096293, "max": 0.7602978746096293}}}
# #metrics {"StartTime": 1675355043.0561967, "EndTime": 1675355043.056209, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.9813548525174459, "count": 1, "min": 0.9813548525174459, "max": 0.9813548525174459}}}
# #metrics {"StartTime": 1675355043.0562565, "EndTime": 1675355043.056272, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.7186806599299113, "count": 1, "min": 0.7186806599299113, "max": 0.7186806599299113}}}
# #metrics {"StartTime": 1675355043.0563242, "EndTime": 1675355043.05634, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 1.0513639847437541, "count": 1, "min": 1.0513639847437541, "max": 1.0513639847437541}}}
# #metrics {"StartTime": 1675355043.0563884, "EndTime": 1675355043.0564034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.9495754837989807, "count": 1, "min": 0.9495754837989807, "max": 0.9495754837989807}}}
# #metrics {"StartTime": 1675355043.0564537, "EndTime": 1675355043.0564706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.785402794679006, "count": 1, "min": 0.785402794679006, "max": 0.785402794679006}}}
# #metrics {"StartTime": 1675355043.0565217, "EndTime": 1675355043.0565372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.7687947154045105, "count": 1, "min": 0.7687947154045105, "max": 0.7687947154045105}}}
# #metrics {"StartTime": 1675355043.0565853, "EndTime": 1675355043.0566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.8011728723843893, "count": 1, "min": 0.8011728723843893, "max": 0.8011728723843893}}}
# #metrics {"StartTime": 1675355043.056649, "EndTime": 1675355043.0566628, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.7671260039011637, "count": 1, "min": 0.7671260039011637, "max": 0.7671260039011637}}}
# #metrics {"StartTime": 1675355043.0567198, "EndTime": 1675355043.0567365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.7396998206774393, "count": 1, "min": 0.7396998206774393, "max": 0.7396998206774393}}}
# #metrics {"StartTime": 1675355043.056787, "EndTime": 1675355043.0568032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 1.0167699853579204, "count": 1, "min": 1.0167699853579204, "max": 1.0167699853579204}}}
# #metrics {"StartTime": 1675355043.0568514, "EndTime": 1675355043.0568674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6767416397730509, "count": 1, "min": 0.6767416397730509, "max": 0.6767416397730509}}}
# #metrics {"StartTime": 1675355043.0569165, "EndTime": 1675355043.0569322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.9052168528238932, "count": 1, "min": 0.9052168528238932, "max": 0.9052168528238932}}}
# #metrics {"StartTime": 1675355043.0569825, "EndTime": 1675355043.0569973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.765836497147878, "count": 1, "min": 0.765836497147878, "max": 0.765836497147878}}}
# #metrics {"StartTime": 1675355043.0570493, "EndTime": 1675355043.057066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.7888709902763367, "count": 1, "min": 0.7888709902763367, "max": 0.7888709902763367}}}
# #metrics {"StartTime": 1675355043.0571177, "EndTime": 1675355043.057134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.783007820447286, "count": 1, "min": 0.783007820447286, "max": 0.783007820447286}}}
# #metrics {"StartTime": 1675355043.0571835, "EndTime": 1675355043.0571995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.7656876842180887, "count": 1, "min": 0.7656876842180887, "max": 0.7656876842180887}}}
# #metrics {"StartTime": 1675355043.057248, "EndTime": 1675355043.0572636, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 1.0480658411979675, "count": 1, "min": 1.0480658411979675, "max": 1.0480658411979675}}}
# #metrics {"StartTime": 1675355043.0573156, "EndTime": 1675355043.057332, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.1022410194079082, "count": 1, "min": 1.1022410194079082, "max": 1.1022410194079082}}}
# #metrics {"StartTime": 1675355043.057382, "EndTime": 1675355043.0573986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.932976504166921, "count": 1, "min": 0.932976504166921, "max": 0.932976504166921}}}
# #metrics {"StartTime": 1675355043.0574627, "EndTime": 1675355043.0574796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9371004501978556, "count": 1, "min": 0.9371004501978556, "max": 0.9371004501978556}}}
# #metrics {"StartTime": 1675355043.057534, "EndTime": 1675355043.0575514, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.421526312828064, "count": 1, "min": 1.421526312828064, "max": 1.421526312828064}}}
# #metrics {"StartTime": 1675355043.057601, "EndTime": 1675355043.0576155, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.461104194323222, "count": 1, "min": 1.461104194323222, "max": 1.461104194323222}}}
# #metrics {"StartTime": 1675355043.0576618, "EndTime": 1675355043.0576766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.2607063055038452, "count": 1, "min": 1.2607063055038452, "max": 1.2607063055038452}}}
# #metrics {"StartTime": 1675355043.0577292, "EndTime": 1675355043.0577466, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.2230856815973918, "count": 1, "min": 1.2230856815973918, "max": 1.2230856815973918}}}
# [02/02/2023 16:24:03 INFO 140073518991168] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.5330592592557272
# [02/02/2023 16:24:03 INFO 140073518991168] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=mse_objective, value=0.5330592592557272
# [02/02/2023 16:24:03 INFO 140073518991168] Epoch 1: Loss improved. Updating best model
# [02/02/2023 16:24:03 INFO 140073518991168] Saving model for epoch: 1
# [02/02/2023 16:24:03 INFO 140073518991168] Saved checkpoint to "/tmp/tmpouy5tz_2/mx-mod-0000.params"
# [02/02/2023 16:24:03 INFO 140073518991168] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1675355042.9571502, "EndTime": 1675355043.067093, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1340.0, "count": 1, "min": 1340, "max": 1340}, "Total Batches Seen": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Max Records Seen Between Resets": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Max Batches Seen Between Resets": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Number of Batches Since Last Reset": {"sum": 4.0, "count": 1, "min": 4, "max": 4}}}
# [02/02/2023 16:24:03 INFO 140073518991168] #throughput_metric: host=algo-1, train throughput=3669.7082985925376 records/second
# #metrics {"StartTime": 1675355043.14867, "EndTime": 1675355043.1487439, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.49771711230278015, "count": 1, "min": 0.49771711230278015, "max": 0.49771711230278015}}}
# #metrics {"StartTime": 1675355043.148836, "EndTime": 1675355043.1488535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.6611820459365845, "count": 1, "min": 0.6611820459365845, "max": 0.6611820459365845}}}
# #metrics {"StartTime": 1675355043.1489134, "EndTime": 1675355043.148931, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.6302621364593506, "count": 1, "min": 0.6302621364593506, "max": 0.6302621364593506}}}
# #metrics {"StartTime": 1675355043.148982, "EndTime": 1675355043.1489968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.9479111035664877, "count": 1, "min": 0.9479111035664877, "max": 0.9479111035664877}}}
# #metrics {"StartTime": 1675355043.1490388, "EndTime": 1675355043.149053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.4410913586616516, "count": 1, "min": 0.4410913586616516, "max": 0.4410913586616516}}}
# #metrics {"StartTime": 1675355043.149095, "EndTime": 1675355043.1491098, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.4549924333890279, "count": 1, "min": 0.4549924333890279, "max": 0.4549924333890279}}}
# #metrics {"StartTime": 1675355043.149153, "EndTime": 1675355043.149166, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.5203223725159963, "count": 1, "min": 0.5203223725159963, "max": 0.5203223725159963}}}
# #metrics {"StartTime": 1675355043.1492076, "EndTime": 1675355043.1492214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.45769168933232623, "count": 1, "min": 0.45769168933232623, "max": 0.45769168933232623}}}
# #metrics {"StartTime": 1675355043.1492653, "EndTime": 1675355043.149279, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.8422188560167948, "count": 1, "min": 0.8422188560167948, "max": 0.8422188560167948}}}
# #metrics {"StartTime": 1675355043.1493223, "EndTime": 1675355043.1493392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.6476330359776815, "count": 1, "min": 0.6476330359776815, "max": 0.6476330359776815}}}
# #metrics {"StartTime": 1675355043.1493802, "EndTime": 1675355043.1493928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.8916800618171692, "count": 1, "min": 0.8916800618171692, "max": 0.8916800618171692}}}
# #metrics {"StartTime": 1675355043.149435, "EndTime": 1675355043.1494486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.8104943831761678, "count": 1, "min": 0.8104943831761678, "max": 0.8104943831761678}}}
# #metrics {"StartTime": 1675355043.1494925, "EndTime": 1675355043.1495056, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.49430006742477417, "count": 1, "min": 0.49430006742477417, "max": 0.49430006742477417}}}
# #metrics {"StartTime": 1675355043.149545, "EndTime": 1675355043.1495593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.4621643324693044, "count": 1, "min": 0.4621643324693044, "max": 0.4621643324693044}}}
# #metrics {"StartTime": 1675355043.1496155, "EndTime": 1675355043.149632, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.5128669937451681, "count": 1, "min": 0.5128669937451681, "max": 0.5128669937451681}}}
# #metrics {"StartTime": 1675355043.1496835, "EndTime": 1675355043.1497002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.47985050082206726, "count": 1, "min": 0.47985050082206726, "max": 0.47985050082206726}}}
# #metrics {"StartTime": 1675355043.1497545, "EndTime": 1675355043.1497712, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.6516849795977274, "count": 1, "min": 0.6516849795977274, "max": 0.6516849795977274}}}
# #metrics {"StartTime": 1675355043.149827, "EndTime": 1675355043.149841, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.8607169191042582, "count": 1, "min": 0.8607169191042582, "max": 0.8607169191042582}}}
# #metrics {"StartTime": 1675355043.149886, "EndTime": 1675355043.1499004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6055883467197418, "count": 1, "min": 0.6055883467197418, "max": 0.6055883467197418}}}
# #metrics {"StartTime": 1675355043.1499574, "EndTime": 1675355043.1499734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7986902594566345, "count": 1, "min": 0.7986902594566345, "max": 0.7986902594566345}}}
# #metrics {"StartTime": 1675355043.1500163, "EndTime": 1675355043.150031, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.5165709952513377, "count": 1, "min": 0.5165709952513377, "max": 0.5165709952513377}}}
# #metrics {"StartTime": 1675355043.1500819, "EndTime": 1675355043.1500974, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.42372267444928485, "count": 1, "min": 0.42372267444928485, "max": 0.42372267444928485}}}
# #metrics {"StartTime": 1675355043.150149, "EndTime": 1675355043.1501644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.4767300883928935, "count": 1, "min": 0.4767300883928935, "max": 0.4767300883928935}}}
# #metrics {"StartTime": 1675355043.1502554, "EndTime": 1675355043.1502728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.5209750731786092, "count": 1, "min": 0.5209750731786092, "max": 0.5209750731786092}}}
# #metrics {"StartTime": 1675355043.1503298, "EndTime": 1675355043.1503468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9786975979804993, "count": 1, "min": 0.9786975979804993, "max": 0.9786975979804993}}}
# #metrics {"StartTime": 1675355043.1504078, "EndTime": 1675355043.1504245, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.0506255229314168, "count": 1, "min": 1.0506255229314168, "max": 1.0506255229314168}}}
# #metrics {"StartTime": 1675355043.1504738, "EndTime": 1675355043.150489, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9618091980616251, "count": 1, "min": 0.9618091980616251, "max": 0.9618091980616251}}}
# #metrics {"StartTime": 1675355043.1505435, "EndTime": 1675355043.1505594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9294426838556925, "count": 1, "min": 0.9294426838556925, "max": 0.9294426838556925}}}
# #metrics {"StartTime": 1675355043.150619, "EndTime": 1675355043.150637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0492917497952778, "count": 1, "min": 1.0492917497952778, "max": 1.0492917497952778}}}
# #metrics {"StartTime": 1675355043.150689, "EndTime": 1675355043.1507046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.0986106395721436, "count": 1, "min": 1.0986106395721436, "max": 1.0986106395721436}}}
# #metrics {"StartTime": 1675355043.150753, "EndTime": 1675355043.150769, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.1416706244150798, "count": 1, "min": 1.1416706244150798, "max": 1.1416706244150798}}}
# #metrics {"StartTime": 1675355043.1508493, "EndTime": 1675355043.1508691, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0715288122495015, "count": 1, "min": 1.0715288122495015, "max": 1.0715288122495015}}}
# [02/02/2023 16:24:03 INFO 140073518991168] #quality_metric: host=algo-1, epoch=2, train mse_objective <loss>=0.49771711230278015
# [02/02/2023 16:24:03 INFO 140073518991168] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=mse_objective, value=0.42372267444928485
# [02/02/2023 16:24:03 INFO 140073518991168] Epoch 2: Loss improved. Updating best model
# [02/02/2023 16:24:03 INFO 140073518991168] Saving model for epoch: 2
# [02/02/2023 16:24:03 INFO 140073518991168] Saved checkpoint to "/tmp/tmpnkjou2d6/mx-mod-0000.params"
# [02/02/2023 16:24:03 INFO 140073518991168] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1675355043.0674062, "EndTime": 1675355043.1640503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1744.0, "count": 1, "min": 1744, "max": 1744}, "Total Batches Seen": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Max Records Seen Between Resets": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Max Batches Seen Between Resets": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Number of Batches Since Last Reset": {"sum": 4.0, "count": 1, "min": 4, "max": 4}}}
# [02/02/2023 16:24:03 INFO 140073518991168] #throughput_metric: host=algo-1, train throughput=4172.029082349929 records/second
# #metrics {"StartTime": 1675355043.262297, "EndTime": 1675355043.2623744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.48568862676620483, "count": 1, "min": 0.48568862676620483, "max": 0.48568862676620483}}}
# #metrics {"StartTime": 1675355043.2625473, "EndTime": 1675355043.262569, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.5864523152510325, "count": 1, "min": 0.5864523152510325, "max": 0.5864523152510325}}}
# #metrics {"StartTime": 1675355043.2626739, "EndTime": 1675355043.2626936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.5589551329612732, "count": 1, "min": 0.5589551329612732, "max": 0.5589551329612732}}}
# #metrics {"StartTime": 1675355043.2627902, "EndTime": 1675355043.2628925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.816428542137146, "count": 1, "min": 0.816428542137146, "max": 0.816428542137146}}}
# #metrics {"StartTime": 1675355043.2629445, "EndTime": 1675355043.2629607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.5739956498146057, "count": 1, "min": 0.5739956498146057, "max": 0.5739956498146057}}}
# #metrics {"StartTime": 1675355043.263009, "EndTime": 1675355043.2630255, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.5651580095291138, "count": 1, "min": 0.5651580095291138, "max": 0.5651580095291138}}}
# #metrics {"StartTime": 1675355043.2630858, "EndTime": 1675355043.2631032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.53562331199646, "count": 1, "min": 0.53562331199646, "max": 0.53562331199646}}}
# #metrics {"StartTime": 1675355043.2631564, "EndTime": 1675355043.2631733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.56524258852005, "count": 1, "min": 0.56524258852005, "max": 0.56524258852005}}}
# #metrics {"StartTime": 1675355043.2632225, "EndTime": 1675355043.2632382, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.7365485429763794, "count": 1, "min": 0.7365485429763794, "max": 0.7365485429763794}}}
# #metrics {"StartTime": 1675355043.263291, "EndTime": 1675355043.2633073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.59853528936704, "count": 1, "min": 0.59853528936704, "max": 0.59853528936704}}}
# #metrics {"StartTime": 1675355043.263367, "EndTime": 1675355043.2633843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.7656316757202148, "count": 1, "min": 0.7656316757202148, "max": 0.7656316757202148}}}
# #metrics {"StartTime": 1675355043.2634382, "EndTime": 1675355043.2634552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.7045811216036478, "count": 1, "min": 0.7045811216036478, "max": 0.7045811216036478}}}
# #metrics {"StartTime": 1675355043.2635055, "EndTime": 1675355043.263522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.5311407446861267, "count": 1, "min": 0.5311407446861267, "max": 0.5311407446861267}}}
# #metrics {"StartTime": 1675355043.263583, "EndTime": 1675355043.2636, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.5548145572344462, "count": 1, "min": 0.5548145572344462, "max": 0.5548145572344462}}}
# #metrics {"StartTime": 1675355043.263659, "EndTime": 1675355043.263676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.5341456631819407, "count": 1, "min": 0.5341456631819407, "max": 0.5341456631819407}}}
# #metrics {"StartTime": 1675355043.2637253, "EndTime": 1675355043.2637415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.5539400080839793, "count": 1, "min": 0.5539400080839793, "max": 0.5539400080839793}}}
# #metrics {"StartTime": 1675355043.2637942, "EndTime": 1675355043.2638102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.5917951862017313, "count": 1, "min": 0.5917951862017313, "max": 0.5917951862017313}}}
# #metrics {"StartTime": 1675355043.263861, "EndTime": 1675355043.2638762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7385979493459066, "count": 1, "min": 0.7385979493459066, "max": 0.7385979493459066}}}
# ...
# #metrics {"StartTime": 1675355044.2389817, "EndTime": 1675355044.2389982, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.3609089255332947, "count": 1, "min": 0.3609089255332947, "max": 0.3609089255332947}}}
# #metrics {"StartTime": 1675355044.2390563, "EndTime": 1675355044.2390735, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.45139432946840924, "count": 1, "min": 0.45139432946840924, "max": 0.45139432946840924}}}
# #metrics {"StartTime": 1675355044.2391255, "EndTime": 1675355044.2391407, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.2663967510064443, "count": 1, "min": 0.2663967510064443, "max": 0.2663967510064443}}}
# #metrics {"StartTime": 1675355044.2391915, "EndTime": 1675355044.2392066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.2677028626203537, "count": 1, "min": 0.2677028626203537, "max": 0.2677028626203537}}}
# #metrics {"StartTime": 1675355044.2392619, "EndTime": 1675355044.2392778, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.2654132793347041, "count": 1, "min": 0.2654132793347041, "max": 0.2654132793347041}}}
# #metrics {"StartTime": 1675355044.239334, "EndTime": 1675355044.2393513, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.2680245091517766, "count": 1, "min": 0.2680245091517766, "max": 0.2680245091517766}}}
# #metrics {"StartTime": 1675355044.239396, "EndTime": 1675355044.2394106, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.427314430475235, "count": 1, "min": 0.427314430475235, "max": 0.427314430475235}}}
# #metrics {"StartTime": 1675355044.239463, "EndTime": 1675355044.2394793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.35851003726323444, "count": 1, "min": 0.35851003726323444, "max": 0.35851003726323444}}}
# #metrics {"StartTime": 1675355044.2395275, "EndTime": 1675355044.2395432, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.4191588560740153, "count": 1, "min": 0.4191588560740153, "max": 0.4191588560740153}}}
# #metrics {"StartTime": 1675355044.2396011, "EndTime": 1675355044.239617, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.3930642207463582, "count": 1, "min": 0.3930642207463582, "max": 0.3930642207463582}}}
# #metrics {"StartTime": 1675355044.2396717, "EndTime": 1675355044.2396886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.2656460205713908, "count": 1, "min": 0.2656460205713908, "max": 0.2656460205713908}}}
# #metrics {"StartTime": 1675355044.2397504, "EndTime": 1675355044.2397676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.2672235121329625, "count": 1, "min": 0.2672235121329625, "max": 0.2672235121329625}}}
# #metrics {"StartTime": 1675355044.2398229, "EndTime": 1675355044.2398388, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.2648603518803914, "count": 1, "min": 0.2648603518803914, "max": 0.2648603518803914}}}
# #metrics {"StartTime": 1675355044.2399027, "EndTime": 1675355044.2399206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.26771901547908783, "count": 1, "min": 0.26771901547908783, "max": 0.26771901547908783}}}
# #metrics {"StartTime": 1675355044.239982, "EndTime": 1675355044.2399976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.38514675696690875, "count": 1, "min": 0.38514675696690875, "max": 0.38514675696690875}}}
# #metrics {"StartTime": 1675355044.2400467, "EndTime": 1675355044.2400596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.4161692460378011, "count": 1, "min": 0.4161692460378011, "max": 0.4161692460378011}}}
# #metrics {"StartTime": 1675355044.2401047, "EndTime": 1675355044.2401142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.38502636551856995, "count": 1, "min": 0.38502636551856995, "max": 0.38502636551856995}}}
# #metrics {"StartTime": 1675355044.240145, "EndTime": 1675355044.2401578, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.447393665711085, "count": 1, "min": 0.447393665711085, "max": 0.447393665711085}}}
# #metrics {"StartTime": 1675355044.2402117, "EndTime": 1675355044.2402282, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.3735031684239705, "count": 1, "min": 0.3735031684239705, "max": 0.3735031684239705}}}
# #metrics {"StartTime": 1675355044.2402825, "EndTime": 1675355044.2402997, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.3696494648853938, "count": 1, "min": 0.3696494648853938, "max": 0.3696494648853938}}}
# #metrics {"StartTime": 1675355044.24035, "EndTime": 1675355044.2403657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.3748852511246999, "count": 1, "min": 0.3748852511246999, "max": 0.3748852511246999}}}
# #metrics {"StartTime": 1675355044.2404172, "EndTime": 1675355044.2404275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.37647774815559387, "count": 1, "min": 0.37647774815559387, "max": 0.37647774815559387}}}
# #metrics {"StartTime": 1675355044.2404644, "EndTime": 1675355044.2404778, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9497852325439453, "count": 1, "min": 0.9497852325439453, "max": 0.9497852325439453}}}
# #metrics {"StartTime": 1675355044.2405288, "EndTime": 1675355044.2405438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9638405243555704, "count": 1, "min": 0.9638405243555704, "max": 0.9638405243555704}}}
# #metrics {"StartTime": 1675355044.2405922, "EndTime": 1675355044.2406077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.945915420850118, "count": 1, "min": 0.945915420850118, "max": 0.945915420850118}}}
# #metrics {"StartTime": 1675355044.2406597, "EndTime": 1675355044.240676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9408614238103231, "count": 1, "min": 0.9408614238103231, "max": 0.9408614238103231}}}
# #metrics {"StartTime": 1675355044.2407262, "EndTime": 1675355044.2407417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9562070369720459, "count": 1, "min": 0.9562070369720459, "max": 0.9562070369720459}}}
# #metrics {"StartTime": 1675355044.2407897, "EndTime": 1675355044.2408059, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9713718295097351, "count": 1, "min": 0.9713718295097351, "max": 0.9713718295097351}}}
# #metrics {"StartTime": 1675355044.2408538, "EndTime": 1675355044.2408686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9762830336888632, "count": 1, "min": 0.9762830336888632, "max": 0.9762830336888632}}}
# #metrics {"StartTime": 1675355044.2409174, "EndTime": 1675355044.2409334, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9854650696118673, "count": 1, "min": 0.9854650696118673, "max": 0.9854650696118673}}}
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.2737799137830734
# [02/02/2023 16:24:04 INFO 140073518991168] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.2648603518803914
# [02/02/2023 16:24:04 INFO 140073518991168] Saving model for epoch: 14
# [02/02/2023 16:24:04 INFO 140073518991168] Saved checkpoint to "/tmp/tmpxo6qprv8/mx-mod-0000.params"
# [02/02/2023 16:24:04 INFO 140073518991168] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1675355044.1779945, "EndTime": 1675355044.2477953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 6592.0, "count": 1, "min": 6592, "max": 6592}, "Total Batches Seen": {"sum": 65.0, "count": 1, "min": 65, "max": 65}, "Max Records Seen Between Resets": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Max Batches Seen Between Resets": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 404.0, "count": 1, "min": 404, "max": 404}, "Number of Batches Since Last Reset": {"sum": 4.0, "count": 1, "min": 4, "max": 4}}}
# [02/02/2023 16:24:04 INFO 140073518991168] #throughput_metric: host=algo-1, train throughput=5777.593409890619 records/second
# [02/02/2023 16:24:04 WARNING 140073518991168] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/02/2023 16:24:04 WARNING 140073518991168] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/02/2023 16:24:04 INFO 140073518991168] #train_score (algo-1) : ('mse_objective', 23.64916191478767)
# [02/02/2023 16:24:04 INFO 140073518991168] #train_score (algo-1) : ('mse', 23.64916191478767)
# [02/02/2023 16:24:04 INFO 140073518991168] #train_score (algo-1) : ('absolute_loss', 3.364224632187645)
# [02/02/2023 16:24:04 INFO 140073518991168] #train_score (algo-1) : ('rmse', 4.8630403982269845)
# [02/02/2023 16:24:04 INFO 140073518991168] #train_score (algo-1) : ('r2', 0.7348029963986331)
# [02/02/2023 16:24:04 INFO 140073518991168] #train_score (algo-1) : ('mae', 3.364224636908805)
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, train mse_objective <loss>=23.64916191478767
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, train mse <loss>=23.64916191478767
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, train absolute_loss <loss>=3.364224632187645
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, train rmse <loss>=4.8630403982269845
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, train r2 <loss>=0.7348029963986331
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, train mae <loss>=3.364224636908805
# [02/02/2023 16:24:04 INFO 140073518991168] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/02/2023 16:24:04 INFO 140073518991168] Saved checkpoint to "/tmp/tmp8jkyy2op/mx-mod-0000.params"
# #metrics {"StartTime": 1675355044.2789605, "EndTime": 1675355044.2846425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 102.0, "count": 1, "min": 102, "max": 102}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 102.0, "count": 1, "min": 102, "max": 102}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 102.0, "count": 1, "min": 102, "max": 102}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [02/02/2023 16:24:04 INFO 140073518991168] #test_score (algo-1) : ('mse_objective', 27.43017338771446)
# [02/02/2023 16:24:04 INFO 140073518991168] #test_score (algo-1) : ('mse', 27.43017338771446)
# [02/02/2023 16:24:04 INFO 140073518991168] #test_score (algo-1) : ('absolute_loss', 3.9059280694699754)
# [02/02/2023 16:24:04 INFO 140073518991168] #test_score (algo-1) : ('rmse', 5.237382302993974)
# [02/02/2023 16:24:04 INFO 140073518991168] #test_score (algo-1) : ('r2', 0.5780325059542923)
# [02/02/2023 16:24:04 INFO 140073518991168] #test_score (algo-1) : ('mae', 3.9059280788197235)
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, test mse_objective <loss>=27.43017338771446
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, test mse <loss>=27.43017338771446
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, test absolute_loss <loss>=3.9059280694699754
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, test rmse <loss>=5.237382302993974
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, test r2 <loss>=0.5780325059542923
# [02/02/2023 16:24:04 INFO 140073518991168] #quality_metric: host=algo-1, test mae <loss>=3.9059280788197235
# #metrics {"StartTime": 1675355042.6335979, "EndTime": 1675355044.288326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 203.765869140625, "count": 1, "min": 203.765869140625, "max": 203.765869140625}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 11.987686157226562, "count": 15, "min": 0.1800060272216797, "max": 1.577615737915039}, "update.time": {"sum": 1354.7725677490234, "count": 15, "min": 67.34013557434082, "max": 113.19923400878906}, "finalize.time": {"sum": 28.340816497802734, "count": 1, "min": 28.340816497802734, "max": 28.340816497802734}, "setuptime": {"sum": 2.298116683959961, "count": 1, "min": 2.298116683959961, "max": 2.298116683959961}, "totaltime": {"sum": 1786.8857383728027, "count": 1, "min": 1786.8857383728027, "max": 1786.8857383728027}}}
#
# 2023-02-02 16:24:13 Uploading - Uploading generated training model
# 2023-02-02 16:24:24 Completed - Training job completed
# Training seconds: 157
# Billable seconds: 157

# %% [markdown]
# # Deploy the model
# ## Here we are going to deploy the model so that we can make some inferences

# %%
# Retrieve model data from training job
training_job_model_data = ll_estimator.model_data
training_job_model_data
# Out:
# 's3://sagemaker-us-east-1-740729256087/housing/output/linear-learner-2023-02-02-16-20-19-995/output/model.tar.gz'

# %%
# Create a unique model name so it won't overwrite ones taht are already there using date and time
deployed_linear_model_name = "boston-housing-deployed-ll-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
print("Model name is " + deployed_linear_model_name)
# Out:
# Model name is boston-housing-deployed-ll-model2023-02-02-16-25-05

# %%
# Container Definition https://docs.aws.amazon.com/sagemaker/latest/APIReference/API_ContainerDefinition.html

client = boto3.client(service_name="sagemaker")

create_model_response = client.create_model(
    ModelName=deployed_linear_model_name,
    Containers=[
        {
            "Image": container, # use the same container defined in the estimator
            "ModelDataUrl": training_job_model_data
        }
    ],
    ExecutionRoleArn=role,
)

print("Model Arn: " + create_model_response["ModelArn"])
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# Model Arn: arn:aws:sagemaker:us-east-1:740729256087:model/boston-housing-deployed-ll-model2023-02-02-16-25-05

# %%
boston_housing_epc_name = "linear-learner-serverless-epc" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

endpoint_config_response = client.create_endpoint_config(
    EndpointConfigName=boston_housing_epc_name,
    ProductionVariants=[
        {
            "VariantName": "llVariant",
            "ModelName": deployed_linear_model_name,
            "ServerlessConfig": {
                "MemorySizeInMB": 4096,
                "MaxConcurrency": 1,
            },
        },
    ],
)

print("Endpoint Configuration Arn: " + endpoint_config_response["EndpointConfigArn"])
# Out:
# Endpoint Configuration Arn: arn:aws:sagemaker:us-east-1:740729256087:endpoint-config/linear-learner-serverless-epc2023-02-02-16-25-06

# %%
boston_housing_ep_name = "linear-learner-serverless-ep" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

create_endpoint_response = client.create_endpoint(
    EndpointName=boston_housing_ep_name,
    EndpointConfigName=boston_housing_epc_name,
)

print("Endpoint Arn: " + create_endpoint_response["EndpointArn"])
# Out:
# Endpoint Arn: arn:aws:sagemaker:us-east-1:740729256087:endpoint/linear-learner-serverless-ep2023-02-02-16-25-06

# %%
# wait for endpoint to reach a terminal state (InService) using describe endpoint
import time

describe_endpoint_response = client.describe_endpoint(EndpointName=boston_housing_ep_name)

while describe_endpoint_response["EndpointStatus"] == "Creating":
    describe_endpoint_response = client.describe_endpoint(EndpointName=boston_housing_ep_name)
    print(describe_endpoint_response["EndpointStatus"])
    time.sleep(15)

describe_endpoint_response
# Out:
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# InService
# {'EndpointName': 'linear-learner-serverless-ep2023-02-02-16-25-06',
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:740729256087:endpoint/linear-learner-serverless-ep2023-02-02-16-25-06',
#  'EndpointConfigName': 'linear-learner-serverless-epc2023-02-02-16-25-06',
#  'ProductionVariants': [{'VariantName': 'llVariant',
#    'DeployedImages': [{'SpecifiedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1',
#      'ResolvedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner@sha256:798a5d87639595079ed13ab06a14139de304f673078a2ef11783fa10cc01896f',
#      'ResolutionTime': datetime.datetime(2023, 2, 2, 16, 25, 7, 683000, tzinfo=tzlocal())}],
#    'CurrentWeight': 1.0,
#    'DesiredWeight': 1.0,
#    'CurrentInstanceCount': 0,
#    'CurrentServerlessConfig': {'MemorySizeInMB': 4096, 'MaxConcurrency': 1}}],
#  'EndpointStatus': 'InService',
#  'CreationTime': datetime.datetime(2023, 2, 2, 16, 25, 7, 2000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2023, 2, 2, 16, 27, 38, 573000, tzinfo=tzlocal()),
#  'ResponseMetadata': {'RequestId': 'b6dae3db-4349-4622-9e69-f253e683d939',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'b6dae3db-4349-4622-9e69-f253e683d939',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '820',
#    'date': 'Thu, 02 Feb 2023 16:27:39 GMT'},
#   'RetryAttempts': 0}}

# %%
runtime = boto3.client(service_name="sagemaker-runtime")

response = runtime.invoke_endpoint(
    EndpointName=boston_housing_ep_name,
    Body="80.0,1.52,0,0.404,7.274,38.3,7.309,2,329.0,12.6,392.2,6.62,0.03768",
    ContentType="text/csv",
)

print(response["Body"].read())
# Out:
# b'{"predictions": [{"score": 34.345664978027344}]}'

# %%
client.delete_model(ModelName=deployed_linear_model_name)
client.delete_endpoint_config(EndpointConfigName=boston_housing_epc_name)
client.delete_endpoint(EndpointName=boston_housing_ep_name)
# Out:
# {'ResponseMetadata': {'RequestId': '4ad33271-97bc-4f30-8d23-a33faa3502cf',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '4ad33271-97bc-4f30-8d23-a33faa3502cf',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Thu, 02 Feb 2023 16:27:54 GMT'},
#   'RetryAttempts': 0}}
