# %% [markdown]
# # Predict a binary value

# %% [markdown]
# ## Linear Learner
#
# https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner.html

# %% [markdown]
# # Prepare the Environment

# %% [markdown]
# ## Upgrade the version of boto3 and sagemaker

# %%
# %pip install -qU --upgrade boto3
# %pip install -qU --upgrade sagemaker
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
import boto3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from time import gmtime, strftime

# %% [markdown]
# ## Setup your your environment variables

# %%
role = get_execution_role()
sess = sagemaker.Session() 
region = sess.boto_session.region_name
bucket = sess.default_bucket()
print("The role is ", role)
print("The session is ", sess)
print("The region is ", region)
print("The bucket is ", bucket)
# Out:
# The role is  arn:aws:iam::740729256087:role/LabRole
# The session is  <sagemaker.session.Session object at 0x7f681f833fd0>
# The region is  us-east-1
# The bucket is  sagemaker-us-east-1-740729256087

# %% [markdown]
# ## We are going to use Linear Learner to make predicitons based on the Diabetes Dataset
#
# ## Diabetes Dataset
# https://www.kaggle.com/datasets/mathchi/diabetes-data-set
#
# ## Context
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective is to predict based on diagnostic measurements whether a patient has diabetes.
#
# ## Content
# Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: Diabetes pedigree function
# * Age: Age (years)
# * Outcome: Class variable (0 or 1)

# %% [markdown]
# # Prepare and Inspect the Data
# ## Download the Dataset to Jupyter Notebook and explore the data by opening it and note that the delimiters are spaces and that there are no headings

# %%
# Load the dataset into a DataFrame usign whitespace as the delimiter.

diabetes_data=pd.read_csv('diabetes.csv')

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Linear learner can read csv but the the first column is assumed to ne the target label so we need to move MEDV to the first column

new_columns = ['Outcome','Pregnancies','Glucose','BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
diabetes_data=diabetes_data.reindex(columns=new_columns)
diabetes_data.head()
# Out:
#    Outcome  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        0            1       85             66             29        0  26.6
# 2        1            8      183             64              0        0  23.3
# 3        0            1       89             66             23       94  28.1
# 4        1            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
# Lets check to see if there are any missing values

diabetes_data.isnull().sum()
# Out:
# Outcome                     0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
# Use describe to get some information about the data

diabetes_data.describe()
# Out:
#           Outcome  Pregnancies     Glucose  BloodPressure  SkinThickness  \
# count  768.000000   768.000000  768.000000     768.000000     768.000000
# mean     0.348958     3.845052  120.894531      69.105469      20.536458
# std      0.476951     3.369578   31.972618      19.355807      15.952218
# min      0.000000     0.000000    0.000000       0.000000       0.000000
# 25%      0.000000     1.000000   99.000000      62.000000       0.000000
# 50%      0.000000     3.000000  117.000000      72.000000      23.000000
# 75%      1.000000     6.000000  140.250000      80.000000      32.000000
# max      1.000000    17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigreeFunction         Age
# count  768.000000  768.000000                768.000000  768.000000
# mean    79.799479   31.992578                  0.471876   33.240885
# std    115.244002    7.884160                  0.331329   11.760232
# min      0.000000    0.000000                  0.078000   21.000000
# 25%      0.000000   27.300000                  0.243750   24.000000
# 50%     30.500000   32.000000                  0.372500   29.000000
# 75%    127.250000   36.600000                  0.626250   41.000000
# max    846.000000   67.100000                  2.420000   81.000000

# %%
# Lets take a look at the correlations

diabetes_data.corr()
# Out:
#                            Outcome  Pregnancies   Glucose  BloodPressure  \
# Outcome                   1.000000     0.221898  0.466581       0.065068
# Pregnancies               0.221898     1.000000  0.129459       0.141282
# Glucose                   0.466581     0.129459  1.000000       0.152590
# BloodPressure             0.065068     0.141282  0.152590       1.000000
# SkinThickness             0.074752    -0.081672  0.057328       0.207371
# Insulin                   0.130548    -0.073535  0.331357       0.088933
# BMI                       0.292695     0.017683  0.221071       0.281805
# DiabetesPedigreeFunction  0.173844    -0.033523  0.137337       0.041265
# Age                       0.238356     0.544341  0.263514       0.239528
#
#                           SkinThickness   Insulin       BMI  \
# Outcome                        0.074752  0.130548  0.292695
# Pregnancies                   -0.081672 -0.073535  0.017683
# Glucose                        0.057328  0.331357  0.221071
# BloodPressure                  0.207371  0.088933  0.281805
# SkinThickness                  1.000000  0.436783  0.392573
# Insulin                        0.436783  1.000000  0.197859
# BMI                            0.392573  0.197859  1.000000
# DiabetesPedigreeFunction       0.183928  0.185071  0.140647
# Age                           -0.113970 -0.042163  0.036242
#
#                           DiabetesPedigreeFunction       Age
# Outcome                                   0.173844  0.238356
# Pregnancies                              -0.033523  0.544341
# Glucose                                   0.137337  0.263514
# BloodPressure                             0.041265  0.239528
# SkinThickness                             0.183928 -0.113970
# Insulin                                   0.185071 -0.042163
# BMI                                       0.140647  0.036242
# DiabetesPedigreeFunction                  1.000000  0.033561
# Age                                       0.033561  1.000000

# %%
# Matplot Heatmap

fig, ax = plt.subplots(figsize=(9,9))
im = ax.imshow(diabetes_data.corr(), interpolation='nearest')
fig.colorbar(im, orientation='vertical')

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Shuffle and Split the data into 80% training and 20% testing

train_data, test_data = train_test_split(diabetes_data, test_size=0.2)

# Convert dataframes to back to CSV files and save them locally to the notebook and make sure to exclude the headers so taht Linear Learner will accept the file

train_data.to_csv('train.csv', header=False, index=False)
test_data.to_csv('test.csv', header=False, index=False)

# %%
# Copy the file to your S3 bucket using sess.upload_data
# You will need to pass the file to be uploaded, a prefix (top level folder to store the data) and the subfolders
# Here we will also define the output folder for the results

prefix = 'diabetes'
training_data_path = sess.upload_data( path='train.csv', key_prefix=prefix + '/input/train') 
testing_data_path = sess.upload_data( path='test.csv', key_prefix=prefix + '/input/test')
output_data_path = 's3://{}/{}/output'.format(bucket, prefix)
print(training_data_path)
print(testing_data_path)
print(output_data_path)
# Out:
# s3://sagemaker-us-east-1-740729256087/diabetes/input/train/train.csv
# s3://sagemaker-us-east-1-740729256087/diabetes/input/test/test.csv
# s3://sagemaker-us-east-1-740729256087/diabetes/output

# %% [markdown]
# # Train the Model

# %%
 # specify containers

from sagemaker.image_uris import retrieve


# List of frameworks that can be retrieved https://sagemaker.readthedocs.io/en/stable/frameworks/index.html
# list of Built-in Algorithms that can be retrieved https://sagemaker.readthedocs.io/en/stable/algorithms/index.html

container = retrieve('linear-learner', region)

# %%
# Amazon Estimator Documentation https://sagemaker.readthedocs.io/en/stable/algorithms/sagemaker.amazon.amazon_estimator.html

from sagemaker.estimator import Estimator 
ll_estimator = Estimator(container, 
                         role=role, 
                         instance_count=1, 
                         instance_type='ml.c4.xlarge', 
                         output_path=output_data_path)

# %%
# Set the linear learner hyperparameters
# hyperparameters can be found here https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html
# Here we will use the Hyperameter values for 


ll_estimator.set_hyperparameters(predictor_type='binary_classifier')

# %%
# Creating a channel from the S3 data source and file system
# TrainingInput documentation https://sagemaker.readthedocs.io/en/stable/api/utility/inputs.html

from sagemaker import TrainingInput 
training_data_channel = TrainingInput( s3_data=training_data_path, content_type='text/csv') 
testing_data_channel = TrainingInput( s3_data=testing_data_path,   content_type='text/csv')

# %% [markdown]
# ## Find the best hyperparameters

# %%
# Hyperparameters = https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html
# Objectives = https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner-tuning.html
# Strategies = 

from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner

hypertuner = HyperparameterTuner(ll_estimator, 
                                 objective_metric_name = 'test:binary_classification_accuracy',
                                 hyperparameter_ranges = {
                                 'learning_rate' : ContinuousParameter(0.01, 0.1),
                                 'mini_batch_size': CategoricalParameter([32,64,128,256,512])},
                                 objective_type = 'Maximize',
                                 metric_definitions = [{'Name': 'est:binary_classification_accuracy', 'Regex': 'loss (\S+)'}],
                                 max_jobs=10, 
                                 max_parallel_jobs=1
                                 )

# %%
hypertuner.fit( {'train': training_data_channel, 'test': testing_data_channel})
# Out:
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# ................................................................................................................................!

# %%
print("Best hyerparameter tuning job:{}".format(hypertuner.best_training_job()))
print("Best parameters found={}".format(hypertuner.best_estimator().hyperparameters()))
# Out:
# Best hyerparameter tuning job:linear-learner-230202-1605-001-a3850aee
#
# 2023-02-02 16:08:59 Starting - Preparing the instances for training
# 2023-02-02 16:08:59 Downloading - Downloading input data
# 2023-02-02 16:08:59 Training - Training image download completed. Training in progress.
# 2023-02-02 16:08:59 Uploading - Uploading generated training model
# 2023-02-02 16:08:59 Completed - Resource reused by training job: linear-learner-230202-1605-002-17f46f3b
# Best parameters found={'_tuning_objective_metric': 'test:binary_classification_accuracy', 'learning_rate': '0.07251566629819672', 'mini_batch_size': '64', 'predictor_type': 'binary_classifier'}

# %% [markdown]
# # Train the Model

# %%
# Set the linear learner hyperparameters
# hyperparameters can be found here https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html
# We will use the values discovered about for learning_rate and mini_batch_size

ll_estimator.set_hyperparameters(predictor_type='binary_classifier',
                                 mini_batch_size=64,
                                 learning_rate=0.07251566629819672)

# %%
# Now we are going to Fit the model
# Documentaiton for FIT https://sagemaker.readthedocs.io/en/stable/algorithms/sagemaker.amazon.amazon_estimator.html#sagemaker.amazon.amazon_estimator.AmazonAlgorithmEstimatorBase.fit

ll_estimator.fit( {'train': training_data_channel, 'test': testing_data_channel})
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2023-02-02-16-20-12-971
# 2023-02-02 16:20:13 Starting - Starting the training job...
# 2023-02-02 16:20:42 Starting - Preparing the instances for training......
# 2023-02-02 16:21:38 Downloading - Downloading input data...
# 2023-02-02 16:22:08 Training - Downloading the training image............
# 2023-02-02 16:23:55 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/02/2023 16:24:02 INFO 140096661559104] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/02/2023 16:24:02 INFO 140096661559104] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'learning_rate': '0.07251566629819672', 'mini_batch_size': '64', 'predictor_type': 'binary_classifier'}
# [02/02/2023 16:24:02 INFO 140096661559104] Final configuration: {'mini_batch_size': '64', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.07251566629819672', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/02/2023 16:24:05 WARNING 140096661559104] Loggers have already been setup.
# [02/02/2023 16:24:05 INFO 140096661559104] Final configuration: {'mini_batch_size': '64', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': '0.07251566629819672', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/02/2023 16:24:05 WARNING 140096661559104] Loggers have already been setup.
# Process 7 is a worker.
# [02/02/2023 16:24:05 INFO 140096661559104] Using default worker.
# [02/02/2023 16:24:05 INFO 140096661559104] Checkpoint loading and saving are disabled.
# [02/02/2023 16:24:05 INFO 140096661559104] Create Store: local
# [02/02/2023 16:24:05 INFO 140096661559104] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f6a41d91d10>
# [02/02/2023 16:24:05 INFO 140096661559104] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [  3.4051864   31.873611    18.597307    16.040216   117.544395
#    7.877559     0.32652554  11.607953  ]
# <NDArray 8 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [  3.888889   119.64411     69.17535     20.862848    80.956604
#   32.02778      0.47339928  32.984375  ]
# <NDArray 8 @cpu(0)>}
# [02/02/2023 16:24:05 INFO 140096661559104] nvidia-smi: took 0.031 seconds to run.
# [02/02/2023 16:24:05 INFO 140096661559104] nvidia-smi identified 0 GPUs.
# [02/02/2023 16:24:05 INFO 140096661559104] Number of GPUs being used: 0
# #metrics {"StartTime": 1675355045.539885, "EndTime": 1675355045.5399153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 678.0, "count": 1, "min": 678, "max": 678}, "Total Batches Seen": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Max Records Seen Between Resets": {"sum": 614.0, "count": 1, "min": 614, "max": 614}, "Max Batches Seen Between Resets": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1675355045.8406024, "EndTime": 1675355045.8406518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5574235320091248, "count": 1, "min": 0.5574235320091248, "max": 0.5574235320091248}}}
# #metrics {"StartTime": 1675355045.8407648, "EndTime": 1675355045.8407786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6592865255143907, "count": 1, "min": 0.6592865255143907, "max": 0.6592865255143907}}}
# #metrics {"StartTime": 1675355045.840843, "EndTime": 1675355045.840854, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6745903028382195, "count": 1, "min": 0.6745903028382195, "max": 0.6745903028382195}}}
# #metrics {"StartTime": 1675355045.840893, "EndTime": 1675355045.8409111, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6536538402239481, "count": 1, "min": 0.6536538402239481, "max": 0.6536538402239481}}}
# #metrics {"StartTime": 1675355045.8409636, "EndTime": 1675355045.840981, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.557413743601905, "count": 1, "min": 0.557413743601905, "max": 0.557413743601905}}}
# #metrics {"StartTime": 1675355045.8410375, "EndTime": 1675355045.8410497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5561719901031918, "count": 1, "min": 0.5561719901031918, "max": 0.5561719901031918}}}
# #metrics {"StartTime": 1675355045.8410964, "EndTime": 1675355045.8411095, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5684628221723769, "count": 1, "min": 0.5684628221723769, "max": 0.5684628221723769}}}
# #metrics {"StartTime": 1675355045.8411686, "EndTime": 1675355045.8411899, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.561201317442788, "count": 1, "min": 0.561201317442788, "max": 0.561201317442788}}}
# #metrics {"StartTime": 1675355045.8412404, "EndTime": 1675355045.8412519, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6534409986601936, "count": 1, "min": 0.6534409986601936, "max": 0.6534409986601936}}}
# #metrics {"StartTime": 1675355045.8413055, "EndTime": 1675355045.841322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6602029734187655, "count": 1, "min": 0.6602029734187655, "max": 0.6602029734187655}}}
# #metrics {"StartTime": 1675355045.8413696, "EndTime": 1675355045.8413794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6010989546775818, "count": 1, "min": 0.6010989546775818, "max": 0.6010989546775818}}}
# #metrics {"StartTime": 1675355046.4811354, "EndTime": 1675355046.481148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6022730469703674, "count": 1, "min": 0.6022730469703674, "max": 0.6022730469703674}}}
# #metrics {"StartTime": 1675355046.4811826, "EndTime": 1675355046.4811957, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5933163364728292, "count": 1, "min": 0.5933163364728292, "max": 0.5933163364728292}}}
# #metrics {"StartTime": 1675355046.481256, "EndTime": 1675355046.481273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5933771000968086, "count": 1, "min": 0.5933771000968086, "max": 0.5933771000968086}}}
# #metrics {"StartTime": 1675355046.4813333, "EndTime": 1675355046.4813507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5835158560011122, "count": 1, "min": 0.5835158560011122, "max": 0.5835158560011122}}}
# #metrics {"StartTime": 1675355046.4814038, "EndTime": 1675355046.4814203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.589271174536811, "count": 1, "min": 0.589271174536811, "max": 0.589271174536811}}}
# #metrics {"StartTime": 1675355046.481463, "EndTime": 1675355046.481479, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5877982179323832, "count": 1, "min": 0.5877982179323832, "max": 0.5877982179323832}}}
# #metrics {"StartTime": 1675355046.4815302, "EndTime": 1675355046.4815462, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.583309617307451, "count": 1, "min": 0.583309617307451, "max": 0.583309617307451}}}
# #metrics {"StartTime": 1675355046.4816089, "EndTime": 1675355046.4816258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6444277630911933, "count": 1, "min": 0.6444277630911933, "max": 0.6444277630911933}}}
# #metrics {"StartTime": 1675355046.4816895, "EndTime": 1675355046.4817078, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6479795244004991, "count": 1, "min": 0.6479795244004991, "max": 0.6479795244004991}}}
# #metrics {"StartTime": 1675355046.4817533, "EndTime": 1675355046.481768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.640976779990726, "count": 1, "min": 0.640976779990726, "max": 0.640976779990726}}}
# #metrics {"StartTime": 1675355046.4818277, "EndTime": 1675355046.4818459, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6460271212789748, "count": 1, "min": 0.6460271212789748, "max": 0.6460271212789748}}}
# #metrics {"StartTime": 1675355046.4819026, "EndTime": 1675355046.4819193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6558839480082194, "count": 1, "min": 0.6558839480082194, "max": 0.6558839480082194}}}
# #metrics {"StartTime": 1675355046.4819765, "EndTime": 1675355046.4819934, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6583838793966506, "count": 1, "min": 0.6583838793966506, "max": 0.6583838793966506}}}
# #metrics {"StartTime": 1675355046.4820578, "EndTime": 1675355046.4820757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6540889342625936, "count": 1, "min": 0.6540889342625936, "max": 0.6540889342625936}}}
# #metrics {"StartTime": 1675355046.482129, "EndTime": 1675355046.4821448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.657264358467526, "count": 1, "min": 0.657264358467526, "max": 0.657264358467526}}}
# [02/02/2023 16:24:06 INFO 140096661559104] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.4683408737182617
# [02/02/2023 16:24:06 INFO 140096661559104] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.4683408737182617
# [02/02/2023 16:24:06 INFO 140096661559104] Epoch 2: Loss improved. Updating best model
# [02/02/2023 16:24:06 INFO 140096661559104] Saving model for epoch: 2
# [02/02/2023 16:24:06 INFO 140096661559104] Saved checkpoint to "/tmp/tmp83mwslh7/mx-mod-0000.params"
# [02/02/2023 16:24:06 INFO 140096661559104] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1675355046.1722152, "EndTime": 1675355046.4901578, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2520.0, "count": 1, "min": 2520, "max": 2520}, "Total Batches Seen": {"sum": 41.0, "count": 1, "min": 41, "max": 41}, "Max Records Seen Between Resets": {"sum": 614.0, "count": 1, "min": 614, "max": 614}, "Max Batches Seen Between Resets": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 614.0, "count": 1, "min": 614, "max": 614}, "Number of Batches Since Last Reset": {"sum": 10.0, "count": 1, "min": 10, "max": 10}}}
# [02/02/2023 16:24:06 INFO 140096661559104] #throughput_metric: host=algo-1, train throughput=1930.3120486786224 records/second
# #metrics {"StartTime": 1675355046.7979658, "EndTime": 1675355046.798007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.46690455741352505, "count": 1, "min": 0.46690455741352505, "max": 0.46690455741352505}}}
# #metrics {"StartTime": 1675355046.798066, "EndTime": 1675355046.7980776, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5611451930469937, "count": 1, "min": 0.5611451930469937, "max": 0.5611451930469937}}}
# #metrics {"StartTime": 1675355046.7981384, "EndTime": 1675355046.7981558, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.575498514705234, "count": 1, "min": 0.575498514705234, "max": 0.575498514705234}}}
# #metrics {"StartTime": 1675355046.798216, "EndTime": 1675355046.7982333, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5608713759316338, "count": 1, "min": 0.5608713759316338, "max": 0.5608713759316338}}}
# #metrics {"StartTime": 1675355046.7982953, "EndTime": 1675355046.7983124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4709369374646081, "count": 1, "min": 0.4709369374646081, "max": 0.4709369374646081}}}
# #metrics {"StartTime": 1675355046.7983615, "EndTime": 1675355046.7983775, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4714345534642537, "count": 1, "min": 0.4714345534642537, "max": 0.4714345534642537}}}
# #metrics {"StartTime": 1675355046.7984352, "EndTime": 1675355046.7984524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4716985457473331, "count": 1, "min": 0.4716985457473331, "max": 0.4716985457473331}}}
# ...
# #metrics {"StartTime": 1675355049.3961837, "EndTime": 1675355049.396192, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.50086643298467, "count": 1, "min": 0.50086643298467, "max": 0.50086643298467}}}
# #metrics {"StartTime": 1675355049.396228, "EndTime": 1675355049.396238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5048335856861539, "count": 1, "min": 0.5048335856861539, "max": 0.5048335856861539}}}
# #metrics {"StartTime": 1675355049.3962686, "EndTime": 1675355049.3962831, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5016465054617988, "count": 1, "min": 0.5016465054617988, "max": 0.5016465054617988}}}
# #metrics {"StartTime": 1675355049.3963454, "EndTime": 1675355049.3963637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4669610129462348, "count": 1, "min": 0.4669610129462348, "max": 0.4669610129462348}}}
# #metrics {"StartTime": 1675355049.3964107, "EndTime": 1675355049.3964307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.46773993637826705, "count": 1, "min": 0.46773993637826705, "max": 0.46773993637826705}}}
# #metrics {"StartTime": 1675355049.39648, "EndTime": 1675355049.396494, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4670196539825863, "count": 1, "min": 0.4670196539825863, "max": 0.4670196539825863}}}
# #metrics {"StartTime": 1675355049.3965478, "EndTime": 1675355049.3965683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4678260286649068, "count": 1, "min": 0.4678260286649068, "max": 0.4678260286649068}}}
# #metrics {"StartTime": 1675355049.3966246, "EndTime": 1675355049.3966389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5754945344395108, "count": 1, "min": 0.5754945344395108, "max": 0.5754945344395108}}}
# #metrics {"StartTime": 1675355049.3967223, "EndTime": 1675355049.3967326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5756865806049771, "count": 1, "min": 0.5756865806049771, "max": 0.5756865806049771}}}
# #metrics {"StartTime": 1675355049.3967962, "EndTime": 1675355049.3968077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5755340788099501, "count": 1, "min": 0.5755340788099501, "max": 0.5755340788099501}}}
# #metrics {"StartTime": 1675355049.396843, "EndTime": 1675355049.3968656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5759574307335747, "count": 1, "min": 0.5759574307335747, "max": 0.5759574307335747}}}
# #metrics {"StartTime": 1675355049.396926, "EndTime": 1675355049.396949, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5810234546661377, "count": 1, "min": 0.5810234546661377, "max": 0.5810234546661377}}}
# #metrics {"StartTime": 1675355049.3970017, "EndTime": 1675355049.3970144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5818237927224901, "count": 1, "min": 0.5818237927224901, "max": 0.5818237927224901}}}
# #metrics {"StartTime": 1675355049.397069, "EndTime": 1675355049.3970854, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.581193917327457, "count": 1, "min": 0.581193917327457, "max": 0.581193917327457}}}
# #metrics {"StartTime": 1675355049.3971403, "EndTime": 1675355049.3971567, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5819450285699632, "count": 1, "min": 0.5819450285699632, "max": 0.5819450285699632}}}
# #metrics {"StartTime": 1675355049.3972034, "EndTime": 1675355049.3972108, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.643662518925137, "count": 1, "min": 0.643662518925137, "max": 0.643662518925137}}}
# #metrics {"StartTime": 1675355049.3972576, "EndTime": 1675355049.3972728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6436683866712782, "count": 1, "min": 0.6436683866712782, "max": 0.6436683866712782}}}
# #metrics {"StartTime": 1675355049.397311, "EndTime": 1675355049.3973305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6437518265512254, "count": 1, "min": 0.6437518265512254, "max": 0.6437518265512254}}}
# #metrics {"StartTime": 1675355049.3973768, "EndTime": 1675355049.3973968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6435425082842509, "count": 1, "min": 0.6435425082842509, "max": 0.6435425082842509}}}
# #metrics {"StartTime": 1675355049.397452, "EndTime": 1675355049.3974679, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6464419232474433, "count": 1, "min": 0.6464419232474433, "max": 0.6464419232474433}}}
# #metrics {"StartTime": 1675355049.3975074, "EndTime": 1675355049.3975272, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6472729047139486, "count": 1, "min": 0.6472729047139486, "max": 0.6472729047139486}}}
# #metrics {"StartTime": 1675355049.3975751, "EndTime": 1675355049.397598, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6464001139005026, "count": 1, "min": 0.6464001139005026, "max": 0.6464001139005026}}}
# #metrics {"StartTime": 1675355049.397649, "EndTime": 1675355049.397669, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6470400094985962, "count": 1, "min": 0.6470400094985962, "max": 0.6470400094985962}}}
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, epoch=10, train binary_classification_cross_entropy_objective <loss>=0.4642910129494137
# [02/02/2023 16:24:09 INFO 140096661559104] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=binary_classification_cross_entropy_objective, value=0.4642910129494137
# [02/02/2023 16:24:09 INFO 140096661559104] Saving model for epoch: 10
# [02/02/2023 16:24:09 INFO 140096661559104] Saved checkpoint to "/tmp/tmpqa85z8w7/mx-mod-0000.params"
# [02/02/2023 16:24:09 INFO 140096661559104] Early stop condition met. Stopping training.
# [02/02/2023 16:24:09 INFO 140096661559104] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1675355049.0887861, "EndTime": 1675355049.4053695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 7432.0, "count": 1, "min": 7432, "max": 7432}, "Total Batches Seen": {"sum": 121.0, "count": 1, "min": 121, "max": 121}, "Max Records Seen Between Resets": {"sum": 614.0, "count": 1, "min": 614, "max": 614}, "Max Batches Seen Between Resets": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 614.0, "count": 1, "min": 614, "max": 614}, "Number of Batches Since Last Reset": {"sum": 10.0, "count": 1, "min": 10, "max": 10}}}
# [02/02/2023 16:24:09 INFO 140096661559104] #throughput_metric: host=algo-1, train throughput=1938.6631315629209 records/second
# [02/02/2023 16:24:09 WARNING 140096661559104] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/02/2023 16:24:09 WARNING 140096661559104] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/02/2023 16:24:09 INFO 140096661559104] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.4719579056730488)
# [02/02/2023 16:24:09 INFO 140096661559104] #train_score (algo-1) : ('binary_classification_accuracy', 0.7768729641693811)
# [02/02/2023 16:24:09 INFO 140096661559104] #train_score (algo-1) : ('binary_f_1.000', 0.6698795180722892)
# [02/02/2023 16:24:09 INFO 140096661559104] #train_score (algo-1) : ('precision', 0.6984924623115578)
# [02/02/2023 16:24:09 INFO 140096661559104] #train_score (algo-1) : ('recall', 0.6435185185185185)
# [02/02/2023 16:24:09 INFO 140096661559104] #train_score (algo-1) : ('roc_auc_score', 0.8417201749488182)
# [02/02/2023 16:24:09 INFO 140096661559104] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/02/2023 16:24:09 INFO 140096661559104] #train_score (algo-1) : ('binary_log_loss', 0.6946597377012794)
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.4719579056730488
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.7768729641693811
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.6698795180722892
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, train precision <score>=0.6984924623115578
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, train recall <score>=0.6435185185185185
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, train roc_auc_score <score>=0.8417201749488182
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, train binary_log_loss <score>=0.6946597377012794
# [02/02/2023 16:24:09 INFO 140096661559104] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.07251566629819672, "l1": 0.0, "wd": 0.0001, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/02/2023 16:24:09 INFO 140096661559104] Saved checkpoint to "/tmp/tmp350jjppk/mx-mod-0000.params"
# #metrics {"StartTime": 1675355049.607635, "EndTime": 1675355049.629764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 154.0, "count": 1, "min": 154, "max": 154}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 154.0, "count": 1, "min": 154, "max": 154}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 154.0, "count": 1, "min": 154, "max": 154}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
# [02/02/2023 16:24:09 INFO 140096661559104] #test_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.47614660510769136)
# [02/02/2023 16:24:09 INFO 140096661559104] #test_score (algo-1) : ('binary_classification_accuracy', 0.7792207792207793)
# [02/02/2023 16:24:09 INFO 140096661559104] #test_score (algo-1) : ('binary_f_1.000', 0.6730769230769231)
# [02/02/2023 16:24:09 INFO 140096661559104] #test_score (algo-1) : ('precision', 0.6730769230769231)
# [02/02/2023 16:24:09 INFO 140096661559104] #test_score (algo-1) : ('recall', 0.6730769230769231)
# [02/02/2023 16:24:09 INFO 140096661559104] #test_score (algo-1) : ('roc_auc_score', 0.82447209653092)
# [02/02/2023 16:24:09 INFO 140096661559104] #test_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/02/2023 16:24:09 INFO 140096661559104] #test_score (algo-1) : ('binary_log_loss', 0.7026413611613306)
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, test binary_classification_cross_entropy_objective <loss>=0.47614660510769136
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.7792207792207793
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.6730769230769231
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, test precision <score>=0.6730769230769231
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, test recall <score>=0.6730769230769231
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, test roc_auc_score <score>=0.82447209653092
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, test binary_balanced_accuracy <score>=0.5
# [02/02/2023 16:24:09 INFO 140096661559104] #quality_metric: host=algo-1, test binary_log_loss <score>=0.7026413611613306
# #metrics {"StartTime": 1675355045.3440688, "EndTime": 1675355049.6342251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 186.88654899597168, "count": 1, "min": 186.88654899597168, "max": 186.88654899597168}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 6.730794906616211, "count": 11, "min": 0.20956993103027344, "max": 1.0554790496826172}, "update.time": {"sum": 3826.643466949463, "count": 11, "min": 309.6630573272705, "max": 429.17490005493164}, "finalize.time": {"sum": 199.14650917053223, "count": 1, "min": 199.14650917053223, "max": 199.14650917053223}, "setuptime": {"sum": 2.2161006927490234, "count": 1, "min": 2.2161006927490234, "max": 2.2161006927490234}, "totaltime": {"sum": 4397.0067501068115, "count": 1, "min": 4397.0067501068115, "max": 4397.0067501068115}}}
#
# 2023-02-02 16:24:27 Uploading - Uploading generated training model
# 2023-02-02 16:24:27 Completed - Training job completed
# Training seconds: 168
# Billable seconds: 168

# %% [markdown]
# # Deploy the model
# ## Here we are going to deploy the model so that we can make some inferences

# %%
# Retrieve model data from training job
training_job_model_data = ll_estimator.model_data
training_job_model_data
# Out:
# 's3://sagemaker-us-east-1-740729256087/diabetes/output/linear-learner-2023-02-02-16-20-12-971/output/model.tar.gz'

# %%
# Create a unique model name so it won't overwrite ones taht are already there using date and time
deployed_linear_model_name = "diabetes-deployed-ll-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
print("Model name is " + deployed_linear_model_name)
# Out:
# Model name is diabetes-deployed-ll-model2023-02-02-16-24-57

# %%
# Container Definition https://docs.aws.amazon.com/sagemaker/latest/APIReference/API_ContainerDefinition.html

client = boto3.client(service_name="sagemaker")

create_model_response = client.create_model(
    ModelName=deployed_linear_model_name,
    Containers=[
        {
            "Image": container, # use the same container defined in the estimator
            "ModelDataUrl": training_job_model_data
        }
    ],
    ExecutionRoleArn=role,
)

print("Model Arn: " + create_model_response["ModelArn"])
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: BaseNotebookInstanceEc2InstanceRole
# Model Arn: arn:aws:sagemaker:us-east-1:740729256087:model/diabetes-deployed-ll-model2023-02-02-16-24-57

# %%
diabetes_epc_name = "linear-learner-serverless-epc" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

endpoint_config_response = client.create_endpoint_config(
    EndpointConfigName=diabetes_epc_name,
    ProductionVariants=[
        {
            "VariantName": "llVariant",
            "ModelName": deployed_linear_model_name,
            "ServerlessConfig": {
                "MemorySizeInMB": 4096,
                "MaxConcurrency": 1,
            },
        },
    ],
)

print("Endpoint Configuration Arn: " + endpoint_config_response["EndpointConfigArn"])
# Out:
# Endpoint Configuration Arn: arn:aws:sagemaker:us-east-1:740729256087:endpoint-config/linear-learner-serverless-epc2023-02-02-16-24-58

# %%
diabetes_ep_name = "linear-learner-serverless-ep" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

create_endpoint_response = client.create_endpoint(
    EndpointName=diabetes_ep_name,
    EndpointConfigName=diabetes_epc_name,
)

print("Endpoint Arn: " + create_endpoint_response["EndpointArn"])
# Out:
# Endpoint Arn: arn:aws:sagemaker:us-east-1:740729256087:endpoint/linear-learner-serverless-ep2023-02-02-16-24-58

# %%
# wait for endpoint to reach a terminal state (InService) using describe endpoint
import time

describe_endpoint_response = client.describe_endpoint(EndpointName=diabetes_ep_name)

while describe_endpoint_response["EndpointStatus"] == "Creating":
    describe_endpoint_response = client.describe_endpoint(EndpointName=diabetes_ep_name)
    print(describe_endpoint_response["EndpointStatus"])
    time.sleep(15)

describe_endpoint_response
# Out:
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# Creating
# InService
# {'EndpointName': 'linear-learner-serverless-ep2023-02-02-16-24-58',
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:740729256087:endpoint/linear-learner-serverless-ep2023-02-02-16-24-58',
#  'EndpointConfigName': 'linear-learner-serverless-epc2023-02-02-16-24-58',
#  'ProductionVariants': [{'VariantName': 'llVariant',
#    'DeployedImages': [{'SpecifiedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1',
#      'ResolvedImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner@sha256:798a5d87639595079ed13ab06a14139de304f673078a2ef11783fa10cc01896f',
#      'ResolutionTime': datetime.datetime(2023, 2, 2, 16, 24, 59, 532000, tzinfo=tzlocal())}],
#    'CurrentWeight': 1.0,
#    'DesiredWeight': 1.0,
#    'CurrentInstanceCount': 0,
#    'CurrentServerlessConfig': {'MemorySizeInMB': 4096, 'MaxConcurrency': 1}}],
#  'EndpointStatus': 'InService',
#  'CreationTime': datetime.datetime(2023, 2, 2, 16, 24, 58, 901000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2023, 2, 2, 16, 27, 30, 512000, tzinfo=tzlocal()),
#  'ResponseMetadata': {'RequestId': 'f7b475f6-75a9-4a73-a4a8-c14a1a352f7d',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f7b475f6-75a9-4a73-a4a8-c14a1a352f7d',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '820',
#    'date': 'Thu, 02 Feb 2023 16:27:30 GMT'},
#   'RetryAttempts': 0}}

# %%
runtime = boto3.client(service_name="sagemaker-runtime")

response = runtime.invoke_endpoint(
    EndpointName=diabetes_ep_name,
    Body="8,197,74,0,0,25.9,1.191,39",
    ContentType="text/csv",
)

print(response["Body"].read())
# Out:
# b'{"predictions": [{"score": 0.932666540145874, "predicted_label": 1}]}'

# %%
client.delete_model(ModelName=deployed_linear_model_name)
client.delete_endpoint_config(EndpointConfigName=diabetes_epc_name)
client.delete_endpoint(EndpointName=diabetes_ep_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'c9c842ee-f906-486c-a783-855d2b4c0b34',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'c9c842ee-f906-486c-a783-855d2b4c0b34',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Thu, 02 Feb 2023 16:27:46 GMT'},
#   'RetryAttempts': 0}}
